# %% [markdown]
# # 1. Load Python Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. Read the Dataset from CSV file - using Pandas

# %%
df = pd.read_csv('/content/Employee_Datasets.csv')
df
# Out:
#      employee_id         department     region         education gender  \
# 0     EMPID65438  Sales & Marketing   region_7  Master's & above      f
# 1     EMPID65141         Operations  region_22        Bachelor's      m
# 2      EMPID7513  Sales & Marketing  region_19        Bachelor's      m
# 3      EMPID2542  Sales & Marketing  region_23        Bachelor's      m
# 4     EMPID48945         Technology  region_26        Bachelor's      m
# ...          ...                ...        ...               ...    ...
# 6601  EMPID48054        Procurement   region_2   Below Secondary      m
# 6602  EMPID10179        Procurement  region_26        Bachelor's      m
# 6603  EMPID23450         Operations  region_15  Master's & above      m
# 6604  EMPID15234  Sales & Marketing  region_31  Master's & above      m
# 6605  EMPID56035                 HR   region_2        Bachelor's      f
#
#      recruitment_channel  Training_Time  age  Prformance_Rating  \
# ...

# %%
# Drop non-imp columns
df.drop(['employee_id','region'], axis=1, inplace=True)
df.head()
# Out:
#           department         education gender recruitment_channel  \
# 0  Sales & Marketing  Master's & above      f            sourcing
# 1         Operations        Bachelor's      m               other
# 2  Sales & Marketing        Bachelor's      m            sourcing
# 3  Sales & Marketing        Bachelor's      m               other
# 4         Technology        Bachelor's      m               other
#
#    Training_Time  age  Prformance_Rating  Years_at_company  Working_Hours  \
# 0              1   35                5.0                 8              8
# 1              1   30                5.0                 4              6
# 2              1   34                3.0                 7              9
# 3              2   39                1.0                10             10
# 4              1   45                3.0                 2              7
#
#   Flexible_Timings Workload_level  Monthly_Income Work_Satisfaction  \
# ...

# %% [markdown]
# # 3. Basic Inspection on given dataset

# %%
df.head()
# Out:
#           department         education gender recruitment_channel  \
# 0  Sales & Marketing  Master's & above      f            sourcing
# 1         Operations        Bachelor's      m               other
# 2  Sales & Marketing        Bachelor's      m            sourcing
# 3  Sales & Marketing        Bachelor's      m               other
# 4         Technology        Bachelor's      m               other
#
#    Training_Time  age  Prformance_Rating  Years_at_company  Working_Hours  \
# 0              1   35                5.0                 8              8
# 1              1   30                5.0                 4              6
# 2              1   34                3.0                 7              9
# 3              2   39                1.0                10             10
# 4              1   45                3.0                 2              7
#
#   Flexible_Timings Workload_level  Monthly_Income Work_Satisfaction  \
# ...

# %%
df.tail()
# Out:
#              department         education gender recruitment_channel  \
# 6601        Procurement   Below Secondary      m            sourcing
# 6602        Procurement        Bachelor's      m               other
# 6603         Operations  Master's & above      m               other
# 6604  Sales & Marketing  Master's & above      m               other
# 6605                 HR        Bachelor's      f               other
#
#       Training_Time  age  Prformance_Rating  Years_at_company  Working_Hours  \
# 6601              4   24                NaN                 1              7
# 6602              1   36                3.0                 6              8
# 6603              2   35                5.0                 3              8
# 6604              1   46                3.0                 7              7
# 6605              1   26                4.0                 2              5
#
#      Flexible_Timings Workload_level  Monthly_Income Work_Satisfaction  \
# ...

# %%
df.shape
# Out:
# (6606, 17)

# %%
len(df)
# Out:
# 6606

# %%
df.size
# Out:
# 112302

# %%
df.columns
# Out:
# Index(['department', 'education', 'gender', 'recruitment_channel',
#        'Training_Time', 'age', 'Prformance_Rating', 'Years_at_company',
#        'Working_Hours', 'Flexible_Timings', 'Workload_level', 'Monthly_Income',
#        'Work_Satisfaction', 'Percent_salary_hike', 'companies_worked',
#        'Marital_Status', 'Stress_status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# department              object
# education               object
# gender                  object
# recruitment_channel     object
# Training_Time            int64
# age                      int64
# Prformance_Rating      float64
# Years_at_company         int64
# Working_Hours            int64
# Flexible_Timings        object
# Workload_level          object
# Monthly_Income           int64
# Work_Satisfaction       object
# Percent_salary_hike      int64
# companies_worked         int64
# Marital_Status          object
# Stress_status           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6606 entries, 0 to 6605
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   department           6606 non-null   object
#  1   education            6282 non-null   object
#  2   gender               6606 non-null   object
#  3   recruitment_channel  6606 non-null   object
#  4   Training_Time        6606 non-null   int64
#  5   age                  6606 non-null   int64
#  6   Prformance_Rating    6108 non-null   float64
#  7   Years_at_company     6606 non-null   int64
#  8   Working_Hours        6606 non-null   int64
#  9   Flexible_Timings     6606 non-null   object
#  10  Workload_level       6606 non-null   object
#  11  Monthly_Income       6606 non-null   int64
#  12  Work_Satisfaction    6606 non-null   object
#  13  Percent_salary_hike  6606 non-null   int64
#  14  companies_worked     6606 non-null   int64
# ...

# %%
print('Check the missing values in each row:')
df.isnull().sum()
# Out:
# Check the missing values in each row:
# department               0
# education              324
# gender                   0
# recruitment_channel      0
# Training_Time            0
# age                      0
# Prformance_Rating      498
# Years_at_company         0
# Working_Hours            0
# Flexible_Timings         0
# Workload_level           0
# Monthly_Income           0
# Work_Satisfaction        0
# Percent_salary_hike      0
# companies_worked         0
# Marital_Status           0
# Stress_status            0
# dtype: int64

# %%
mode_education = df['education'].mode()[0]
df['education'].fillna(mode_education,inplace=True)

df['Prformance_Rating'].fillna(df['Prformance_Rating'].mean(),inplace=True)

# %%
print('Check the missing values in each row:')
df.isnull().sum()
# Out:
# Check the missing values in each row:
# department             0
# education              0
# gender                 0
# recruitment_channel    0
# Training_Time          0
# age                    0
# Prformance_Rating      0
# Years_at_company       0
# Working_Hours          0
# Flexible_Timings       0
# Workload_level         0
# Monthly_Income         0
# Work_Satisfaction      0
# Percent_salary_hike    0
# companies_worked       0
# Marital_Status         0
# Stress_status          0
# dtype: int64

# %%
df.describe().T
# Out:
#                       count          mean           std      min      25%  \
# Training_Time        6606.0      1.250530      0.603594      1.0      1.0
# age                  6606.0     34.768090      7.701359     20.0     29.0
# Prformance_Rating    6606.0      3.335134      1.199229      1.0      3.0
# Years_at_company     6606.0      5.896609      4.315779      1.0      3.0
# Working_Hours        6606.0      7.930366      1.180460      4.0      7.0
# Monthly_Income       6606.0  46331.092946  16572.609461  18000.0  39000.0
# Percent_salary_hike  6606.0     32.861944     62.819005      8.0     21.0
# companies_worked     6606.0      3.630639      1.192886      1.0      3.0
#
#                          50%      75%      max
# Training_Time            1.0      1.0     10.0
# age                     33.0     39.0     60.0
# Prformance_Rating        3.0      4.0      6.0
# Years_at_company         5.0      7.0     34.0
# Working_Hours            8.0      9.0     10.0
# ...

# %% [markdown]
# # 4. Categorical Variable Analysis

# %%
#!pip install tabulate

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from tabulate import tabulate
class BarPieChartTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        df=X.copy()
        # get cat columns
        cat_cols = df.select_dtypes(include='object').columns
        for cat_name in cat_cols:
            value_counts = df[cat_name].value_counts().reset_index()
            # Rename the columns
            value_counts.columns = ['Class', 'Frequency']

            # Print the result as a table
            print(f"{cat_name} frequency table")
            print(tabulate(value_counts, headers='keys', tablefmt='pretty'))

            # Calculate relative frequency
            total_count = value_counts['Frequency'].sum()
            value_counts['Relative Frequency %'] = round((value_counts['Frequency'] / total_count)*100,2)

            # Print the result as a table
            print(f"{cat_name} Relative frequency table")
            print(tabulate(value_counts, headers='keys', tablefmt='pretty'))

            # Extract the values and index from value counts
            value_counts = df[cat_name].value_counts()
            values = value_counts.values
            labels = value_counts.index

            fig, axs = plt.subplots(1, 2, figsize=(12, 6))  # 1 row, 2 columns
            # Create a bar graph
            axs[0].bar(labels, values)
            axs[0].set_title(f'Frequency of {cat_name}')
            axs[0].set_xlabel('Categories')  # Set x-label
            axs[0].set_ylabel('Count')       # Set y-label

            axs[1].pie(value_counts.values, labels=value_counts.index, autopct='%1.1f%%', startangle=140)
            axs[1].set_title(f'Relative Frequency of {cat_name}')
            plt.tight_layout()
            # Show the plot
            plt.show()

pipeline_cat_var = Pipeline([
    ('cat_univaraite_analysis', BarPieChartTransformer())
])

# Fit and transform your data using the pipeline
processed_data = pipeline_cat_var.fit_transform(df)
# Out:
# department frequency table
# +---+-------------------+-----------+
# |   |       Class       | Frequency |
# +---+-------------------+-----------+
# | 0 | Sales & Marketing |   1991    |
# | 1 |    Operations     |   1330    |
# | 2 |    Technology     |    902    |
# | 3 |    Procurement    |    884    |
# | 4 |     Analytics     |    684    |
# | 5 |      Finance      |    286    |
# | 6 |        HR         |    280    |
# | 7 |       Legal       |    128    |
# | 8 |        R&D        |    121    |
# +---+-------------------+-----------+
# department Relative frequency table
# +---+-------------------+-----------+----------------------+
# |   |       Class       | Frequency | Relative Frequency % |
# +---+-------------------+-----------+----------------------+
# | 0 | Sales & Marketing |   1991    |        30.14         |
# | 1 |    Operations     |   1330    |        20.13         |
# | 2 |    Technology     |    902    |        13.65         |
# ...

# %% [markdown]
# # 5. Numerical Variable Analysis

# %%
class HistBoxChartTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        df=X.copy()
        # getting num cols
        num_cols = df.select_dtypes(exclude='object').columns
        for con_var in num_cols:

            # Create a figure and axes object
            fig, axes = plt.subplots(1, 2, figsize=(14, 6))

            # Plot histogram without KDE on the left
            axes[0].hist(df[con_var], color='skyblue', edgecolor='black')
            axes[0].set_xlabel('Value')
            axes[0].set_ylabel('Frequency')
            axes[0].set_title(f'Histogram {con_var}')

            # Plot histogram with KDE on the right
            sns.histplot(data=df, x=con_var, kde=True, color='orange', edgecolor='black', ax=axes[1])
            axes[1].set_xlabel('Value')
            axes[1].set_ylabel('Density')
            axes[1].set_title('Histogram with KDE')

            # Adjust layout
            plt.tight_layout()

            # Show the combined plot
            plt.show()
pipeline_num_var = Pipeline([
    ('num_uni_variate_analysis', HistBoxChartTransformer())
])

# Fit and transform your data using the pipeline
processed_data = pipeline_num_var.fit_transform(df)

# %% [markdown]
# # 6. Outlier Analysis

# %%
# Function to remove outliers using the IQR method
def remove_outliers(df):
    # Select only numeric columns
    numeric_cols = df.select_dtypes(include=['number']).columns
    for col in numeric_cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    return df

# Remove outliers
cleaned_data = remove_outliers(df)

# Recalculate the correlation matrix
correlation_matrix = cleaned_data.corr(numeric_only=True)

# Save the cleaned dataset and correlation matrix for review
cleaned_data.to_csv('cleaned_employee_survey.csv', index=False)
#correlation_matrix.to_csv('correlation_matrix.csv')

print("Outliers removed and correlation matrix recalculated.")
# Out:
# Outliers removed and correlation matrix recalculated.

# %%
cleaned_data = pd.read_csv('/content/cleaned_employee_survey.csv')
cleaned_data
# Out:
#              department         education gender recruitment_channel  \
# 0     Sales & Marketing  Master's & above      f            sourcing
# 1            Operations        Bachelor's      m               other
# 2     Sales & Marketing        Bachelor's      m            sourcing
# 3            Technology        Bachelor's      m               other
# 4            Operations        Bachelor's      f               other
# ...                 ...               ...    ...                 ...
# 3516  Sales & Marketing        Bachelor's      f            sourcing
# 3517          Analytics        Bachelor's      m            sourcing
# 3518        Procurement        Bachelor's      m               other
# 3519  Sales & Marketing  Master's & above      m               other
# 3520                 HR        Bachelor's      f               other
#
#       Training_Time  age  Prformance_Rating  Years_at_company  Working_Hours  \
# ...

# %% [markdown]
# # 7. Bi Variate Analysis

# %%
cat_vars = cleaned_data.select_dtypes(include='object').columns
print(cat_vars)
# Out:
# Index(['department', 'education', 'gender', 'recruitment_channel',
#        'Flexible_Timings', 'Workload_level', 'Work_Satisfaction',
#        'Marital_Status', 'Stress_status'],
#       dtype='object')

# %% [markdown]
# ## 7.1 Cat vs Cat

# %%
target = "Stress_status"
fig,ax = plt.subplots(2,2,figsize=(20,14))
for axi,x in zip(ax.flat,cat_vars):
    col1=cleaned_data[x]
    col2=cleaned_data[target]
    result=pd.crosstab(col1,col2)
    print(result)
    print("===============================")
    result.plot(kind='bar',ax=axi)
# Out:
# Stress_status       No  Yes
# department
# Analytics          135  211
# Finance             68   98
# HR                  78   97
# Legal               29   43
# Operations         263  521
# Procurement        172  279
# R&D                 17   32
# Sales & Marketing  362  690
# Technology         153  273
# ...
# Stress_status      No   Yes
# education
# Bachelor's        918  1640
# Below Secondary    27    33
# Master's & above  332   571
# ...
# Stress_status   No   Yes
# gender
# f              378   714
# m              899  1530
# ...
# Stress_status         No   Yes
# recruitment_channel
# other                728  1240
# referred              35    59
# sourcing             514   945
# ...

# %% [markdown]
# ## 7.2 Num Vs Num

# %%
corr_mat = cleaned_data.corr(numeric_only=True)
plt.figure(figsize=(11,11))
sns.heatmap(corr_mat, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # 8. Convert Cat-to-Numerical Columns

# %%
cat_cols = cleaned_data.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['department', 'education', 'gender', 'recruitment_channel',
#        'Flexible_Timings', 'Workload_level', 'Work_Satisfaction',
#        'Marital_Status', 'Stress_status'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for var in cat_cols:
    cleaned_data[var]=le.fit_transform(cleaned_data[var])

# %%
cleaned_data.to_csv('labelled_data.csv', index=False)
cleaned_data
# Out:
#       department  education  gender  recruitment_channel  Training_Time  age  \
# 0              7          2       0                    2              1   35
# 1              4          0       1                    0              1   30
# 2              7          0       1                    2              1   34
# 3              8          0       1                    0              1   45
# 4              4          0       0                    0              1   31
# ...          ...        ...     ...                  ...            ...  ...
# 3516           7          0       0                    2              1   27
# 3517           0          0       1                    2              1   41
# 3518           5          0       1                    0              1   36
# 3519           7          2       1                    0              1   46
# 3520           2          0       0                    0              1   26
#
# ...

# %% [markdown]
# # 9. Standardization - Normalization

# %%
from sklearn.preprocessing import StandardScaler

scalar = StandardScaler()
scaled_feature = scalar.fit_transform(cleaned_data) # fit_transform the data without target column

# Create new dataframe with scaled data
scaled_df = pd.DataFrame(scaled_feature, columns=cleaned_data.columns)
#scaled_df['Stress_status'] = cleaned_data['Stress_status']
scaled_df
# Out:
#       department  education    gender  recruitment_channel  Training_Time  \
# 0       0.847479   1.684006 -1.491429             1.172811            0.0
# 1      -0.352832  -0.607101  0.670498            -0.876553            0.0
# 2       0.847479  -0.607101  0.670498             1.172811            0.0
# 3       1.247582  -0.607101  0.670498            -0.876553            0.0
# 4      -0.352832  -0.607101 -1.491429            -0.876553            0.0
# ...          ...        ...       ...                  ...            ...
# 3516    0.847479  -0.607101 -1.491429             1.172811            0.0
# 3517   -1.953247  -0.607101  0.670498             1.172811            0.0
# 3518    0.047272  -0.607101  0.670498            -0.876553            0.0
# 3519    0.847479   1.684006  0.670498            -0.876553            0.0
# 3520   -1.153039  -0.607101 -1.491429            -0.876553            0.0
#
#            age  Prformance_Rating  Years_at_company  Working_Hours  \
# ...

# %% [markdown]
# # 10. SMOTE for Balancing Data

# %%
#!pip install imbalanced-learn  # Install the 'imblearn' library

# %%
X = scaled_df.drop('Stress_status', axis=1)
Y = scaled_df['Stress_status'].astype(int)

from imblearn.over_sampling import SMOTE
X, Y = SMOTE().fit_resample(X,Y)
print(X.columns)
print(len(X), len(Y))
# Out:
# Index(['department', 'education', 'gender', 'recruitment_channel',
#        'Training_Time', 'age', 'Prformance_Rating', 'Years_at_company',
#        'Working_Hours', 'Flexible_Timings', 'Workload_level', 'Monthly_Income',
#        'Work_Satisfaction', 'Percent_salary_hike', 'companies_worked',
#        'Marital_Status'],
#       dtype='object')
# 4488 4488

# %%
X = scaled_df.drop(columns=['Stress_status'])
Y = scaled_df['Stress_status']
scaled_df
# Out:
#       department  education    gender  recruitment_channel  Training_Time  \
# 0       0.847479   1.684006 -1.491429             1.172811            0.0
# 1      -0.352832  -0.607101  0.670498            -0.876553            0.0
# 2       0.847479  -0.607101  0.670498             1.172811            0.0
# 3       1.247582  -0.607101  0.670498            -0.876553            0.0
# 4      -0.352832  -0.607101 -1.491429            -0.876553            0.0
# ...          ...        ...       ...                  ...            ...
# 3516    0.847479  -0.607101 -1.491429             1.172811            0.0
# 3517   -1.953247  -0.607101  0.670498             1.172811            0.0
# 3518    0.047272  -0.607101  0.670498            -0.876553            0.0
# 3519    0.847479   1.684006  0.670498            -0.876553            0.0
# 3520   -1.153039  -0.607101 -1.491429            -0.876553            0.0
#
#            age  Prformance_Rating  Years_at_company  Working_Hours  \
# ...

# %%
#scaled_df.to_csv('preprocessed_data.csv', index=False)

# %% [markdown]
# # 11. Train-Test-Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (2816, 16)
# (705, 16)
# (2816,)
# (705,)

# %% [markdown]
# # 12. Perform the ML Algorithms without Hyper-Parameter Tuning

# %%
from sklearn.metrics import accuracy_score, \
                            precision_score, recall_score, \
                            confusion_matrix, ConfusionMatrixDisplay, f1_score

def metric_classification(y_pred, y_test):
    acc = round(accuracy_score(y_test, y_pred) * 100, 2)
    f1 = round(f1_score(y_test, y_pred, average='weighted'), 2)
    precision = round(precision_score(y_test, y_pred, average='weighted'), 2)
    recall = round(recall_score(y_test, y_pred, average='weighted'), 2)

    print("Accuracy:", acc)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)

    cmt = confusion_matrix(y_test, y_pred)

    disp = ConfusionMatrixDisplay(confusion_matrix=cmt, display_labels=np.unique(Y_test))
    disp.plot()
    plt.grid(False)
    plt.show()

    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    print("True Negative:", tn)
    print("False Positive:", fp)
    print("False Negative:", fn)
    print("True Positive:", tp)

    return acc, f1, precision, recall

# %%
result_dict = {}

# %% [markdown]
# ## 12.1 Logistic Regression

# %%
# Before fitting the Logistic Regression model, convert Y_train to integers:
Y_train = Y_train.astype(int)

from sklearn.linear_model import LogisticRegression

lg_model = LogisticRegression()
lg_model.fit(X_train, Y_train)
print("Model - Logistic Regression")

score = lg_model.score(X_train, Y_train)
print('accuracy train score overall :', score)

# Convert Y_test to integers before calculating the score:
Y_test = Y_test.astype(int)
score = lg_model.score(X_test, Y_test)
print('accuracy test score overall :', score)

y_pred_log=lg_model.predict(X_test)
result_dict["Logistic"]=metric_classification(y_pred_log,Y_test)
# Out:
# Model - Logistic Regression
# accuracy train score overall : 0.6392045454545454
# accuracy test score overall : 0.6312056737588653
# Accuracy: 63.12
# Precision: 0.4
# Recall: 0.63
# F1 Score: 0.49
# True Negative: 0
# False Positive: 260
# False Negative: 0
# True Positive: 445

# %% [markdown]
# ## 12.2 KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, Y_train)
print("Model - KNN")

score = knn.score(X_train, Y_train)
print('accuracy train score overall :', score)
score = knn.score(X_test, Y_test)
print('accuracy test score overall :', score)

Y_predict_knn = knn.predict(X_test)
result_dict['KNN'] = metric_classification(Y_test, Y_predict_knn)
# Out:
# Model - KNN
# accuracy train score overall : 0.7024147727272727
# accuracy test score overall : 0.5475177304964539
# Accuracy: 54.75
# Precision: 0.61
# Recall: 0.55
# F1 Score: 0.57
# True Negative: 57
# False Positive: 116
# False Negative: 203
# True Positive: 329

# %% [markdown]
# ## 12.3 Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, Y_train)
print("Model - Naive Bayes")

score = nb.score(X_train, Y_train)
print('accuracy train score overall :', score)
score = nb.score(X_test, Y_test)
print('accuracy test score overall :', score)

Y_predict_nb = nb.predict(X_test)
result_dict['Naive Bayes'] = metric_classification(Y_test, Y_predict_nb)
# Out:
# Model - Naive Bayes
# accuracy train score overall : 0.6374289772727273
# accuracy test score overall : 0.6283687943262412
# Accuracy: 62.84
# Precision: 0.97
# Recall: 0.63
# F1 Score: 0.76
# True Negative: 4
# False Positive: 6
# False Negative: 256
# True Positive: 439

# %% [markdown]
# ## 12.4 Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, Y_train)
print("Model - Decision Tree")

score = model.score(X_train, Y_train)
print('accuracy train score overall :', score)
score = model.score(X_test, Y_test)
print('accuracy test score overall :', score)

y_pred = model.predict(X_test)
result_dict['Decision Tree'] = metric_classification(y_pred, Y_test)
# Out:
# Model - Decision Tree
# accuracy train score overall : 0.9996448863636364
# accuracy test score overall : 0.5219858156028369
# Accuracy: 52.2
# Precision: 0.53
# Recall: 0.52
# F1 Score: 0.52
# True Negative: 100
# False Positive: 160
# False Negative: 177
# True Positive: 268

# %% [markdown]
# ## 12.5 Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfr = RandomForestClassifier()
rfr.fit(X_train, Y_train)
print("Model - Random Forest")

score = rfr.score(X_train, Y_train)
print('accuracy train score overall :', score)
score = rfr.score(X_test, Y_test)
print('accuracy test score overall :', score)

prediction = rfr.predict(X_test)
result_dict['Random Forest'] = metric_classification(prediction, Y_test)
# Out:
# Model - Random Forest
# accuracy train score overall : 0.9996448863636364
# accuracy test score overall : 0.6070921985815603
# Accuracy: 60.71
# Precision: 0.54
# Recall: 0.61
# F1 Score: 0.53
# True Negative: 28
# False Positive: 232
# False Negative: 45
# True Positive: 400

# %% [markdown]
# ## 12.6 Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier()
model.fit(X_train, Y_train)
print("Model - Gradient Boosting")

score = model.score(X_train, Y_train)
print('accuracy train score overall :', score)
score = model.score(X_test, Y_test)
print('accuracy test score overall :', score)

y_pred = model.predict(X_test)
result_dict['Gradient Boosting'] = metric_classification(y_pred, Y_test)
# Out:
# Model - Gradient Boosting
# accuracy train score overall : 0.6839488636363636
# accuracy test score overall : 0.6184397163120567
# Accuracy: 61.84
# Precision: 0.53
# Recall: 0.62
# F1 Score: 0.51
# True Negative: 11
# False Positive: 249
# False Negative: 20
# True Positive: 425

# %% [markdown]
# ## 12.7 Adaptive Boosting

# %%
from sklearn.ensemble import AdaBoostClassifier
adaboost_model = AdaBoostClassifier()
adaboost_model.fit(X_train, Y_train)
print("Model - Adaptive Boosting")

score = adaboost_model.score(X_train, Y_train)
print('accuracy train score overall :', score)
score = adaboost_model.score(X_test, Y_test)
print('accuracy test score overall :', score)

y_pred = adaboost_model.predict(X_test)
result_dict['AdaBoost'] = metric_classification(y_pred, Y_test)
# Out:
# Model - Adaptive Boosting
# accuracy train score overall : 0.6395596590909091
# accuracy test score overall : 0.6312056737588653
# Accuracy: 63.12
# Precision: 0.4
# Recall: 0.63
# F1 Score: 0.49
# True Negative: 0
# False Positive: 260
# False Negative: 0
# True Positive: 445

# %% [markdown]
# # 12.8 Support Vector Machine(SVM)

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# Initialize SVM model
svm_model = SVC()

# Fit the model
svm_model.fit(X_train, Y_train)
print("Model - Support Vector Machine")

# Train and test accuracy scores
score = svm_model.score(X_train, Y_train)
print('accuracy train score overall :', score)

score = svm_model.score(X_test, Y_test)
print('accuracy test score overall :', score)

# Make predictions on the test set
y_pred = svm_model.predict(X_test)

# Assuming you have a function 'metric_classification' to evaluate the results
result_dict['SVM'] = metric_classification(y_pred, Y_test)
# Out:
# Model - Support Vector Machine
# accuracy train score overall : 0.6548295454545454
# accuracy test score overall : 0.6269503546099291
# Accuracy: 62.7
# Precision: 0.47
# Recall: 0.63
# F1 Score: 0.49
# True Negative: 1
# False Positive: 259
# False Negative: 4
# True Positive: 441

# %% [markdown]
# ## 12.9 K-Means Clustering

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

def metric_clustering(X_data, n_clusters):

    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(X_data)

    # Get the cluster centers and the labels for each data point
    cluster_centers = kmeans.cluster_centers_
    labels = kmeans.labels_

    # Calculate the silhouette score (optional but gives insight into clustering quality)
    silhouette_avg = silhouette_score(X_data, labels)

    print("Silhouette Score:", round(silhouette_avg, 2))

    # Visualize the clusters (works well for 2D data, use PCA or t-SNE for higher-dimensional data)
    if X_data.shape[1] == 2:
        plt.figure(figsize=(10, 6))
        plt.scatter(X_data[:, 0], X_data[:, 1], c=labels, cmap='viridis')
        plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], marker='X', color='red', s=200, label='Centroids')
        plt.title("K-Means Clustering")
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.legend()
        plt.show()
    else:
        print("For visualization, data must be 2D. Use PCA or t-SNE for higher-dimensional data.")

    return kmeans, labels, cluster_centers

# Apply KMeans with 3 clusters (you can change n_clusters to whatever number you prefer)
n_clusters = 3
kmeans_model, cluster_labels, cluster_centers = metric_clustering(X_train, n_clusters)

# Optionally, you can apply the model to the test data
# test_labels = kmeans_model.predict(X_test)  # If you want to predict on new data
# Out:
# Silhouette Score: 0.08
# For visualization, data must be 2D. Use PCA or t-SNE for higher-dimensional data.

# %%
from sklearn.decomposition import PCA

# Reduce the dimensions of the data to 2D for visualization
pca = PCA(n_components=2)
X_train_2d = pca.fit_transform(X_train)

# Now apply KMeans on this reduced 2D data
n_clusters = 3
kmeans_model, cluster_labels, cluster_centers = metric_clustering(X_train_2d, n_clusters)
# Out:
# Silhouette Score: 0.44

# %%
result = pd.DataFrame(result_dict, index=['Accuracy', "F1 score",'Precision','Recall'])
result
# Out:
#            Logistic    KNN  Naive Bayes  Decision Tree  Random Forest  \
# Accuracy      63.12  54.75        62.84          52.20          60.71
# F1 score       0.49   0.57         0.76           0.52           0.53
# Precision      0.40   0.61         0.97           0.53           0.54
# Recall         0.63   0.55         0.63           0.52           0.61
#
#            Gradient Boosting  AdaBoost    SVM
# Accuracy               61.84     63.12  62.70
# F1 score                0.51      0.49   0.49
# Precision               0.53      0.40   0.47
# Recall                  0.62      0.63   0.63

# %% [markdown]
# # 13. Perform ML with Hyper-Parameter Tuning

# %% [markdown]
# ## 13.1 Logistic Regression

# %%
result_hpt = {}

# %%
from sklearn.model_selection import GridSearchCV

logistic_regression = LogisticRegression(class_weight='balanced')

# Define the hyperparameters to search through
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],  # Inverse of regularization strength
    'penalty': ['l1', 'l2'],               # Regularization penalty
}

# Define the GridSearchCV object
grid_search = GridSearchCV(logistic_regression, param_grid, cv=5, scoring='accuracy')

# Fit the GridSearchCV object to the data
grid_search.fit(X_train, Y_train)

# Print the best hyperparameters found
print("Best hyperparameters:", grid_search.best_params_)

# Print the best cross-validation score found
print("Best cross-validation score:", grid_search.best_score_)
result_hpt['Logistic'] = grid_search.best_score_
# Out:
# Best hyperparameters: {'C': 0.01, 'penalty': 'l2'}
# Best cross-validation score: 0.5181247874229999

# %% [markdown]
# ## 13.2 KNN

# %%
knn = KNeighborsClassifier()

# Define the hyperparameters to search through
param_grid = {
    'n_neighbors': [3, 5, 7, 9],  # Number of neighbors to consider
    'weights': ['uniform', 'distance'],  # Weight function used in prediction
    'metric': ['euclidean', 'manhattan']  # Distance metric
}

# Define the GridSearchCV object
grid_search = GridSearchCV(knn, param_grid, cv=5, scoring='accuracy')

# Fit the GridSearchCV object to the data
grid_search.fit(X_train, Y_train)

# Print the best hyperparameters found
print("Best hyperparameters:", grid_search.best_params_)

# Print the best cross-validation score found
print("Best cross-validation score:", grid_search.best_score_)
result_hpt['KNN'] = grid_search.best_score_
# Out:
# Best hyperparameters: {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'uniform'}
# Best cross-validation score: 0.5667592557600494

# %% [markdown]
# ## 13.3 Decision Tree

# %%
dtree = DecisionTreeClassifier(class_weight='balanced')

param_grid = {
    'max_depth': [3,  5,  7, 9, 11],
    'min_samples_split': [2, 3, 4],
    'min_samples_leaf': [1, 2, 3, 4],
    'random_state': [0, 42],
    'criterion':["gini", "entropy"]
}

# Perform a grid search with cross-validation to find the best hyperparameters
grid_search = GridSearchCV(dtree, param_grid, cv=5,scoring='accuracy')
grid_search.fit(X_train, Y_train)

# Print the best hyperparameters
print("Best hyperparameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
result_hpt['DT'] = grid_search.best_score_
# Out:
# Best hyperparameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 0}
# Best cross-validation score: 0.5461729841401811

# %% [markdown]
# ## 13.4 Random Forest

# %%
rfc = RandomForestClassifier(class_weight='balanced')
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 5, 10],
    'max_features': ['sqrt', 'log2', None],
    'random_state': [0, 42],
    'criterion':["gini", "entropy"]
}

# Perform a grid search with cross-validation to find the best hyperparameters
grid_search = GridSearchCV(rfc, param_grid, cv=5)
grid_search.fit(X_train, Y_train)

# Print the best hyperparameters
print(grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
print("Best cross-validation score:", grid_search.best_score_)
result_hpt['Random Forest'] = grid_search.best_score_
# Out:
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200, 'random_state': 42}
# Best cross-validation score: 0.6228688762077523
# Best cross-validation score: 0.6228688762077523

# %% [markdown]
# ## 13.5 Gradient Boosting

# %%
#!pip install lightgbm

# %%
import lightgbm as lgb

lgbm = lgb.LGBMClassifier(class_weight='balanced',random_state=42)

# Define the parameter grid for LightGBM
param_grid_lgbm = {
    'n_estimators': [100, 200],
    'max_depth': [None, 5, 10],
    'learning_rate': [0.01, 0.1, 0.2],
    'num_leaves': [31, 63],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0],
    'random_state': [42]
}

# Perform GridSearchCV to find the best hyperparameters
grid_search_lgbm = GridSearchCV(lgbm, param_grid_lgbm, cv=5)
grid_search_lgbm.fit(X_train, Y_train)


print("Best LightGBM parameters:", grid_search_lgbm.best_params_)
print("Best cross-validation score:", grid_search_lgbm.best_score_)
result_hpt['LightGBM'] = grid_search_lgbm.best_score_
# Out:
# Streaming output truncated to the last 5000 lines.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# ## 13.6 Adaptive Boosting

# %%
abc = AdaBoostClassifier()

# Define the parameter grid for AdaBoost
#param_grid = {
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 1],
    'random_state': [0, 42],
}

# Perform a grid search with cross-validation to find the best hyperparameters
grid_search = GridSearchCV(abc, param_grid, cv=5)
grid_search.fit(X_train, Y_train)

# Print the best hyperparameters
print(grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
result_hpt['AdaBoost'] = grid_search.best_score_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 100, 'random_state': 0}
# Best cross-validation score: 0.6388496277540532

# %% [markdown]
# ## 13.7 SVM

# %%
# Initialize SVM model
svm = SVC(class_weight='balanced',random_state=42)

# Define the parameter grid for SVM
param_grid_svm = {
    'C': [0.1, 1, 10],  # Regularization parameter
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],  # Kernel types
    'degree': [3, 4, 5],  # Only for 'poly' kernel
    'gamma': ['scale', 'auto'],  # Kernel coefficient
    'coef0': [0, 1],  # Only for 'poly' and 'sigmoid' kernels
    'class_weight': [None, 'balanced']  # Handling class imbalance
}

# Perform GridSearchCV to find the best hyperparameters
grid_search_svm = GridSearchCV(svm, param_grid_svm, cv=5)
grid_search_svm.fit(X_train, Y_train)

# Output the best parameters and best cross-validation score
print("Best SVM parameters:", grid_search_svm.best_params_)
print("Best cross-validation score:", grid_search_svm.best_score_)

# Store the best score in the result dictionary
result_hpt['SVM'] = grid_search_svm.best_score_
# Out:
# Best SVM parameters: {'C': 0.1, 'class_weight': None, 'coef0': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# Best cross-validation score: 0.6395619969010997

# %%
result
# Out:
#            Logistic    KNN  Naive Bayes  Decision Tree  Random Forest  \
# Accuracy      63.12  54.75        62.84          52.20          60.71
# F1 score       0.49   0.57         0.76           0.52           0.53
# Precision      0.40   0.61         0.97           0.53           0.54
# Recall         0.63   0.55         0.63           0.52           0.61
#
#            Gradient Boosting  AdaBoost    SVM
# Accuracy               61.84     63.12  62.70
# F1 score                0.51      0.49   0.49
# Precision               0.53      0.40   0.47
# Recall                  0.62      0.63   0.63

# %%
result_hpt = pd.DataFrame(result_hpt, index=['Accuracy'])
result_hpt
# Out:
#           Logistic       KNN        DT  Random Forest  LightGBM  AdaBoost  \
# Accuracy  0.518125  0.566759  0.546173       0.622869  0.536944   0.63885
#
#                SVM
# Accuracy  0.639562

# %% [markdown]
# # 14. Final - Model - Without Hyper Parameter - Random Forest

# %%
from sklearn.metrics import classification_report

#logistic = LogisticRegression(class_weight='balanced', C=1, penalty='l2')
rfr = RandomForestClassifier()
#adaboost_model = AdaBoostClassifier()
rfr.fit(X_train, Y_train)

#svm = SVC(C=0.1, class_weight=None, coef0=1, degree=3, gamma='scale', kernel='poly')
#logistic.fit(X_train, Y_train)
print("Model- Random Forest")

accuracy=rfr.score(X_train, Y_train)
print(f"train score: {accuracy}")

accuracy=rfr.score(X_test, Y_test)
print(f"test score: {accuracy}")

y_pred = rfr.predict(X_test)
metric_classification(y_pred,Y_test)

print(classification_report(Y_test, y_pred))
# Out:
# Model- Random Forest
# train score: 0.9996448863636364
# test score: 0.6085106382978723
# Accuracy: 60.85
# Precision: 0.54
# Recall: 0.61
# F1 Score: 0.53
# True Negative: 28
# False Positive: 232
# False Negative: 44
# True Positive: 401
#               precision    recall  f1-score   support
#
#           -1       0.39      0.11      0.17       260
#            0       0.63      0.90      0.74       445
#
#     accuracy                           0.61       705
#    macro avg       0.51      0.50      0.46       705
# weighted avg       0.54      0.61      0.53       705

# %% [markdown]
# # 15. Save the model using pickle

# %%
import pickle
filename = 'rf_model.pkl'
with open(filename, 'wb') as file:
    pickle.dump(rfr, file)

print(f"Model saved to {filename}")
# Out:
# Model saved to rf_model.pkl
